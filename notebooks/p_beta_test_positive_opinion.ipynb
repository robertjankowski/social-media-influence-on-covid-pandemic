# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('../')

import scripts.visualization as viz
from scripts.data_utils import load_results

viz.load_matplotlib()
plt = viz.plt

# %% [markdown]
# # Large network
#
# ## Parameters
#
#
# - $\beta$ = {0.1, 0.3, 0.5, 0.7}
# - $\gamma$ = 0.5
# - $\mu$ = 0.85
# - $\kappa$ = 0.1
# - q = 3
# - max_infected_time = 10
# - NSTEPS = 200 000
# - NAGENTS = 10 000
# - NFRACLINKS = 0.1
# - n_runs = 1 (only one realization !!)

# %%
dr_beta_1_params, dr_beta_1_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/dead_ratio_p_3_q_positive_opinion_L1-beta=0.1_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
dr_beta_2_params, dr_beta_2_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/dead_ratio_p_3_q_positive_opinion_L1-beta=0.3_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
dr_beta_3_params, dr_beta_3_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/dead_ratio_p_3_q_positive_opinion_L1-beta=0.5_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
dr_beta_4_params, dr_beta_4_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/dead_ratio_p_3_q_positive_opinion_L1-beta=0.7_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")

# %%
ir_beta_1_params, ir_beta_1_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/infected_ratio_p_3_q_positive_opinion_L1-beta=0.1_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
ir_beta_2_params, ir_beta_2_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/infected_ratio_p_3_q_positive_opinion_L1-beta=0.3_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
ir_beta_3_params, ir_beta_3_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/infected_ratio_p_3_q_positive_opinion_L1-beta=0.5_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
ir_beta_4_params, ir_beta_4_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/infected_ratio_p_3_q_positive_opinion_L1-beta=0.7_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")

# %%
opinion_beta_1_params, opinion_beta_1_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/mean_opinion_p_3_q_positive_opinion_L1-beta=0.1_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
opinion_beta_2_params, opinion_beta_2_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/mean_opinion_p_3_q_positive_opinion_L1-beta=0.3_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
opinion_beta_3_params, opinion_beta_3_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/mean_opinion_p_3_q_positive_opinion_L1-beta=0.5_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")
opinion_beta_4_params, opinion_beta_4_df = load_results(
    "../data/new_experiments/p_beta_positive_opinion/mean_opinion_p_3_q_positive_opinion_L1-beta=0.7_gamma=0.5_mu=0.85_kappa=0.1_max_infected_time=10_L2-q=4_p=0.5_xi=0.1_n=100_NRUNS=1_NSTEPS=200000_NAGENTS=10000_NFRACLINKS=0.1.csv")

# %%
colors = ['red', 'green', 'blue', 'black']
colors = ['xkcd:' + c for c in colors]
markers = ['o', 's', 'v', '^']
markersize = 6

labels = [fr'$\beta$={x}' for x in [0.1, 0.3, 0.5, 0.7]]
ps = [float(x) for x in opinion_beta_1_df.columns]
ys = [opinion_beta_1_df, opinion_beta_2_df, opinion_beta_3_df, opinion_beta_4_df]

for i, y in enumerate(ys):
    plt.plot(ps, y.values[0], color=colors[i], label=labels[i], marker=markers[i],
             markersize=markersize)

plt.ylabel('opinion', fontsize=20)
plt.xlabel('p', fontsize=20)
plt.legend()

# %%
ys = [dr_beta_1_df, dr_beta_2_df, dr_beta_3_df, dr_beta_4_df]

for i, y in enumerate(ys):
    plt.plot(ps, y.values[0], color=colors[i], label=labels[i], marker=markers[i],
             markersize=markersize)

plt.ylabel('dead rate', fontsize=20)
plt.xlabel('p', fontsize=20)
plt.legend()

# %%
ys = [ir_beta_1_df, ir_beta_2_df, ir_beta_3_df, ir_beta_4_df]

for i, y in enumerate(ys):
    plt.plot(ps, y.values[0], color=colors[i], label=labels[i], marker=markers[i],
             markersize=markersize)

plt.ylabel('max infected rate', fontsize=20)
plt.xlabel('p', fontsize=20)
plt.legend()

# %%
# TODO -- prepare raport !!
